# %% [markdown]
# <a href="https://colab.research.google.com/github/aniket9608/Machine_learning_practice/blob/main/campusXwevScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# if response code is 403

# headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} -

# requests.get('url',headers=headers).text

# %%
import requests

url = 'https://internshala.com/fresher-jobs/work-from-home/'

# Mimic a standard desktop Chrome browser browser session
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5'
}

try:
    # Setting a timeout ensures your script won't hang indefinitely
    response = requests.get(url, headers=headers, timeout=10)
    print(f"Status Code: {response.status_code}")
    w = response.text
except requests.exceptions.Timeout:
    print("The request timed out because the server took too long to respond.")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# Status Code: 200

# %%
w=requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

# %%
s=BeautifulSoup(w,'html.parser')

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
#   <meta content="702141670710132" property="fb:app_id"/>
#   <meta content="website" property="og:type"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <link as="image" href="https://internshala.com//static/images/home/sprites/img-assets.png" rel="preload"/>
#   <link as="image" href="https://internshala.com/static/images/internship/banners/jobs_banner_r767.png" media="(max-width: 767px)" rel="preload"/>
#   <link as="image" href="https://internshala.com/static/images/internship/banners/jobs_banner_r1920.png" media="(min-width: 767.1px)" rel="preload"/>
# ...

# %%
s.find_all('a',id_='job_title')
# Out:
# []

# %%
for i in s.find('a',id_='job_title'):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2755/3493591006.py in <cell line: 0>()
# ----> 1 for i in s.find('a',id_='job_title'):
#       2   print(i)
#
# TypeError: 'NoneType' object is not iterable

# %%
company=s.find_all('div',class_='company-content-wrapper')

# %%
name=[]
rating=[]
ctype=[]

for i in company:
  name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_='rating').text.strip())
  ctype.append(i.find('p',class_='infoEntity')[0].text.strip())


d={'name':name ,'rating': rating,'CompanyType':ctype}

df=pd.DataFrame(d)

# %%
df

# %%
#  run loop for different page using page =1
